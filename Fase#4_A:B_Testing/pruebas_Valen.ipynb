# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import chi2_contingency, ttest_ind

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv('..\Fase1_y_2_EDA&Limpiza_Data/df_transformado_limpio.csv')
df.sample(5)
# Out:
#      employeenumber  age attrition     businesstravel  dailyrate  \
# 865            2240   27        No      travel rarely     1450.0
# 756           13080   58        No      travel rarely      848.0
# 241            6820   53        No      travel rarely      238.0
# 835           18560   47        No      travel rarely      207.0
# 694            7540   43        No  travel frequently      775.0
#
#      distancefromhome  education educationfield  environmentsatisfaction  \
# 865                 3          3  life sciences                        3
# 756                23          4  life sciences                        1
# 241                 1          1  life sciences                        4
# 835                 9          4  life sciences                        2
# 694                15          3  life sciences                        4
#
#      gender  hourlyrate  jobinvolvement  joblevel                  jobrole  \
# 865    Male          79               2         1      research scientist
# 756    Male          88               3         1      research scientist
# 241  Female          34               3         2         sales executive
# 835  Female          64               3         1   laboratory technician
# 694    Male          47               2         2         sales executive
#
#      jobsatisfaction maritalstatus  monthlyincome  monthlyrate  \
# 865                3      divorced        25660.0        25326
# 756                3       married        48620.0        26076
# 241                1        single        48620.0         7507
# 835                3        single        21050.0         5411
# 694                4       married        48620.0        23683
#
#      numcompaniesworked overtime  percentsalaryhike  performancerating  \
# 865                   1       No                 15                3.0
# 756                   1       No                 12                3.0
# 241                   7       No                 20                4.0
# 835                   4       No                 12                3.0
# 694                   3       No                 18                3.2
#
#      relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 865                         4                 1                1.0
# 756                         4                 2               10.0
# 241                         4                 0               18.0
# 835                         3                 0               10.0
# 694                         3                 1                7.0
#
#      trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 865                      2              2.0               1
# 756                      3              3.0               2
# 241                      2              4.0              14
# 835                      2              3.0               2
# 694                      5              3.0               2
#
#      yearssincelastpromotion  yearswithcurrmanager  datebirth remotework
# 865                        0                     1       1996        Yes
# 756                        2                     2       1965        Yes
# 241                        8                    10       1970         No
# 835                        2                     0       1976         No
# 694                        2                     2       1980        Yes

# %%
# Crear la columna 'group' usando where 

df['group_AB_Testing'] = df['jobsatisfaction'].where(df['jobsatisfaction'] >= 3, 'A').where(df['jobsatisfaction'] < 3, 'B')

# %%
#df_chi.head()

# %%
# Filtrar el DataFrame para obtener solo los datos del grupo 'A'
grupo_a = df[df['group_AB_Testing'] == 'A']
grupo_a
# Out:
#       employeenumber  age attrition businesstravel  dailyrate  \
# 5                810   59        No  travel rarely     1435.0
# 11              8250   58       Yes  travel rarely      286.0
# 15             12940   36        No  travel rarely      429.0
# 20              1000   35        No  travel rarely      776.0
# 21              2440   46        No  travel rarely      526.0
# ...              ...  ...       ...            ...        ...
# 1069           19350   56        No  travel rarely     1443.0
# 1070           19360   39        No  travel rarely      867.0
# 1073           19440   27       Yes  travel rarely     1337.0
# 1074           19610   38        No  travel rarely     1404.0
# 1078           20230   23       Yes  travel rarely      638.0
#
#       distancefromhome  education educationfield  environmentsatisfaction  \
# 5                   25          3  life sciences                        1
# 11                   2          4  life sciences                        4
# 15                   2          4  life sciences                        3
# 20                   1          4      marketing                        3
# 21                   1          2  life sciences                        2
# ...                ...        ...            ...                      ...
# 1069                11          5  life sciences                        4
# 1070                 9          2  life sciences                        1
# 1073                22          3  life sciences                        1
# 1074                 1          3  life sciences                        1
# 1078                 9          3  life sciences                        4
#
#       gender  hourlyrate  jobinvolvement  joblevel                   jobrole  \
# 5     Female          99               3         3          sales executive
# 11      Male          31               3         5        research director
# 15    Female          53               3         2   manufacturing director
# 20      Male          32               2         2          sales executive
# 21    Female          92               3         3          sales executive
# ...      ...         ...             ...       ...                       ...
# 1069  Female          89               2         2          sales executive
# 1070    Male          87               3         2   manufacturing director
# 1073  Female          58               2         1          human resources
# 1074    Male          59               2         1     sales representative
# 1078    Male          33               3         1     sales representative
#
#       jobsatisfaction maritalstatus  monthlyincome  monthlyrate  \
# 5                   1       married        48620.0         2354
# 11                  2        single       192460.0        25761
# 15                  2        single        48620.0         2323
# 20                  1        single        48620.0        23016
# 21                  1      divorced        48620.0         2137
# ...               ...           ...            ...          ...
# 1069                1       married        48620.0        20328
# 1070                1       married        51510.0        12315
# 1073                2       married        28630.0        19555
# 1074                1        single        28580.0        11473
# 1078                1       married        48620.0        26956
#
#       numcompaniesworked overtime  percentsalaryhike  performancerating  \
# 5                      7       No                 11                3.0
# 11                     7      Yes                 12                3.0
# 15                     9      Yes                 11                3.0
# 20                     0       No                 14                3.2
# 21                     1       No                 25                4.0
# ...                  ...      ...                ...                ...
# 1069                   4       No                 16                3.0
# 1070                   1       No                 25                4.0
# 1073                   1       No                 12                3.0
# 1074                   4       No                 14                3.0
# 1078                   1       No                 19                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 5                            4                 0               28.0
# 11                           4                 0               40.0
# 15                           4                 0               18.0
# 20                           2                 0               16.0
# 21                           3                 3               24.0
# ...                        ...               ...                ...
# 1069                         3                 1               10.0
# 1070                         4                 1               10.0
# 1073                         1                 0               10.0
# 1074                         1                 0               20.0
# 1078                         1                 1               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 5                         3              2.0              21
# 11                        2              3.0              31
# 15                        2              3.0              16
# 20                        2              3.0              15
# 21                        2              3.0              24
# ...                     ...              ...             ...
# 1069                      3              3.0               0
# 1070                      3              3.0              10
# 1073                      2              3.0               1
# 1074                      3              2.0               1
# 1078                      3              2.8               1
#
#       yearssincelastpromotion  yearswithcurrmanager  datebirth remotework  \
# 5                           7                     9       1964        Yes
# 11                         13                     8       1965         No
# 15                          5                    12       1987         No
# 20                          2                     8       1988         No
# 21                         15                     7       1977        Yes
# ...                       ...                   ...        ...        ...
# 1069                        0                     0       1967        Yes
# 1070                        7                     9       1984        Yes
# 1073                        0                     0       1996         No
# 1074                        0                     0       1985        Yes
# 1078                        1                     0       2000         No
#
#      group_AB_Testing
# 5                   A
# 11                  A
# 15                  A
# 20                  A
# 21                  A
# ...               ...
# 1069                A
# 1070                A
# 1073                A
# 1074                A
# 1078                A
#
# [415 rows x 33 columns]

# %%
grupo_a['attrition'].value_counts()
# Out:
# attrition
# No     332
# Yes     83
# Name: count, dtype: int64

# %%
a_rotacion = round ((83 / 415), 2) # 2 porcentaje de rotación 
a_rotacion
# Out:
# 0.2

# %%
# Filtrar el DataFrame para obtener solo los datos del grupo 'A'
grupo_b = df[df['group_AB_Testing'] == 'B']
grupo_b
# Out:
#       employeenumber  age attrition businesstravel  dailyrate  \
# 0               1620   51        No  travel rarely      684.0
# 1               2590   52        No  travel rarely      699.0
# 2               3190   42        No  travel rarely      532.0
# 3              20681   47        No  travel rarely      359.0
# 4              19000   48        No  travel rarely      117.0
# ...              ...  ...       ...            ...        ...
# 1072           19430   42        No  travel rarely      419.0
# 1075           19660   32        No  travel rarely     1373.0
# 1076           19740   31        No  travel rarely     1276.0
# 1077           20120   40        No  travel rarely      543.0
# 1079           20400   35        No  travel rarely     1146.0
#
#       distancefromhome  education    educationfield  environmentsatisfaction  \
# 0                    6          3     life sciences                        1
# 1                    1          4     life sciences                        3
# 2                    4          2  technical degree                        3
# 3                    2          4           medical                        1
# 4                   22          3           medical                        4
# ...                ...        ...               ...                      ...
# 1072                12          4         marketing                        2
# 1075                 5          4     life sciences                        4
# 1076                 2          1           medical                        4
# 1077                44          4     life sciences                        1
# 1079                26          4     life sciences                        3
#
#       gender  hourlyrate  jobinvolvement  joblevel                   jobrole  \
# 0       Male          51               3         5        research director
# 1       Male          65               2         5                  manager
# 2       Male          58               3         5                  manager
# 3     Female          82               3         4        research director
# 4     Female          58               3         4                  manager
# ...      ...         ...             ...       ...                       ...
# 1072    Male          77               3         2          sales executive
# 1075    Male          56               2         2   manufacturing director
# 1076  Female          59               1         1    laboratory technician
# 1077    Male          83               3         1    laboratory technician
# 1079  Female          31               3         3          human resources
#
#       jobsatisfaction maritalstatus  monthlyincome  monthlyrate  \
# 0                   3       married       195370.0         6462
# 1                   3       married       199990.0         5678
# 2                   4       married       192320.0         4933
# 3                   3       married       171690.0        26703
# 4                   4       married       171740.0         2437
# ...               ...           ...            ...          ...
# 1072                4      divorced        48620.0         2900
# 1075                4       married        48620.0        10138
# 1076                4       married        11290.0        17536
# 1077                4       married        48620.0         4060
# 1079                4        single        48620.0        16642
#
#       numcompaniesworked overtime  percentsalaryhike  performancerating  \
# 0                      7       No                 13                3.0
# 1                      0       No                 14                3.0
# 2                      1       No                 11                3.0
# 3                      3       No                 19                3.0
# 4                      3       No                 11                3.0
# ...                  ...      ...                ...                ...
# 1072                   3       No                 12                3.2
# 1075                   8       No                 24                4.0
# 1076                   1       No                 11                3.0
# 1077                   8       No                 19                3.0
# 1079                   1      Yes                 16                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 0                            3                 0               10.0
# 1                            1                 1               34.0
# 2                            4                 0               22.0
# 3                            2                 2               10.0
# 4                            2                 1               10.0
# ...                        ...               ...                ...
# 1072                         3                 2               14.0
# 1075                         2                 0               10.0
# 1076                         3                 3               10.0
# 1077                         3                 2                8.0
# 1079                         3                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 0                         5              3.0              20
# 1                         5              3.0              33
# 2                         3              2.8              22
# 3                         2              2.8              20
# 4                         3              3.0              22
# ...                     ...              ...             ...
# 1072                      4              3.0               0
# 1075                      1              3.0               1
# 1076                      4              3.0               1
# 1077                      3              2.0               1
# 1079                      2              2.8               9
#
#       yearssincelastpromotion  yearswithcurrmanager  datebirth remotework  \
# 0                          15                    15       1972        Yes
# 1                          11                     9       1971        Yes
# 2                          11                    15       1981        Yes
# 3                           5                     6       1976         No
# 4                           4                     7       1975        Yes
# ...                       ...                   ...        ...        ...
# 1072                        0                     0       1981         No
# 1075                        0                     0       1991        Yes
# 1076                        0                     0       1992        Yes
# 1077                        0                     0       1983        Yes
# 1079                        1                     7       1988         No
#
#      group_AB_Testing
# 0                   B
# 1                   B
# 2                   B
# 3                   B
# 4                   B
# ...               ...
# 1072                B
# 1075                B
# 1076                B
# 1077                B
# 1079                B
#
# [665 rows x 33 columns]

# %%
grupo_b['attrition'].value_counts()
# Out:
# attrition
# No     571
# Yes     94
# Name: count, dtype: int64

# %%
b_rotacion = round ((94 / 665), 2) # 2 porcentaje de rotación 
b_rotacion
# Out:
# 0.14

# %%
# Agrego la columna de rotacion
df['rotacion'] = np.where(df['group_AB_Testing'] == 'A', a_rotacion, b_rotacion)

# %% [markdown]
# Normalidad

# %%
#evaluamos Normalidad
# lo primero que hacemos es crear una función para testar la normalidad de los datos
def normalidad(dataframe, columna):
    statistic, p_value = stats.shapiro(dataframe[columna])
    if p_value > 0.05:
        print(f"Para la columna {columna} los datos siguen una distribución normal.")
    else:
        print(f"Para la columna {columna} los datos no siguen una distribución normal.")

# %%
normalidad(df ,'rotacion')
# Out:
# Para la columna rotacion los datos no siguen una distribución normal.

# %% [markdown]
# Homogeneidad

# %%
def homogeneidad (dataframe, columna, columna_metrica):    
    # lo primero que tenemos que hacer es crear tantos conjuntos de datos para cada una de las categorías que tenemos, Control Campaign y Test Campaign
    valores_evaluar = []
    
    for valor in dataframe[columna].unique():
        valores_evaluar.append(dataframe[dataframe[columna]== valor][columna_metrica])

    statistic, p_value = stats.levene(*valores_evaluar)
    if p_value > 0.05:
        print(f"Para la métrica {columna_metrica} las varianzas son homogéneas entre grupos.")
    else:
        print(f"Para la métrica {columna_metrica}, las varianzas no son homogéneas entre grupos.")

# %%
homogeneidad(df ,'attrition', 'rotacion')
# Out:
# Para la métrica rotacion, las varianzas no son homogéneas entre grupos.

# %% [markdown]
# Independencia

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Prueba de Proporciones (chi-cuadrado)

# %%
#creamos un DF con variables numericas y relevantes
df_chi = df[['rotacion', 'attrition']]
df_chi.head()
# Out:
#    rotacion attrition
# 0      0.14        No
# 1      0.14        No
# 2      0.14        No
# 3      0.14        No
# 4      0.14        No

# %% [markdown]
# no tiene sentido hacer matriz de correlaciones con las columnas rotacion y grupo.

# %%
# Visualizar la matriz de correlación con tamaño ajustado
correlacion_matrix = df_chi.corr()
plt.figure(figsize=(10, 8))  # Ajustar el tamaño de la figura
sns.heatmap(correlacion_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Visualizar la matriz de correlación con tamaño ajustado
# ----> 2 correlacion_matrix = df_chi.corr()
#       3 plt.figure(figsize=(10, 8))  # Ajustar el tamaño de la figura
#       4 sns.heatmap(correlacion_matrix, annot=True, cmap="coolwarm", fmt=".2f")
#
# File c:\Users\matia\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\matia\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\matia\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\matia\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'No'

# %%
# Crear una tabla de contingencia
contingency_table = pd.crosstab(df['rotacion'], df['attrition'])

# Realizar la prueba de proporciones
chi2, p_value, _, _ = chi2_contingency(contingency_table)

# Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa en la tasa de rotación entre el Grupo A y el Grupo B.")
    print("\n ---------- \n")
    print("""
          Los resultados sugieren que existe evidencia estadística para afirmar que las medias de las muestras son distintas. 
          Por lo tanto, el nivel de satisfacción de el empleado influye en la desición de abandonar la empresa   
          """)
else:
    print("No hay evidencia de una diferencia significativa en la tasa de rotación entre el Grupo A y el Grupo B.")
    print("\n ---------- \n")
    print(""" 
          Los resultados sugieren que no existe evidencia estadística para afirmar que las medias de las muestras son distintas,
          por lo que el nivel de satisfacción de el empleado NO influye en la desición de abandonar la empresa  
          """)
# Out:
# Hay una diferencia significativa en la tasa de rotación entre el Grupo A y el Grupo B.
#
#  ----------
#
#
#           Los resultados sugieren que existe evidencia estadística para afirmar que las medias de las muestras son distintas.
#           Por lo tanto, el nivel de satisfacción de el empleado influye en la desición de abandonar la empresa

# %%
p_value
# Out:
# 0.014362771751750169
