# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Realizar los distintos test
# ------------------------------------------------------------------------------

from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway
from sklearn.linear_model import LinearRegression


# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_ab_testing = pd.read_csv('df_transformado_limpio.csv')
df_ab_testing.sample(5)
# Out:
#      employeenumber  age attrition businesstravel  dailyrate  \
# 501            3900   26        No  travel rarely      496.0
# 356             620   46        No  travel rarely     1211.0
# 476           19090   41        No  travel rarely      337.0
# 194             980   31        No  travel rarely      746.0
# 503            4220   58        No  travel rarely      390.0
#
#      distancefromhome  education educationfield  environmentsatisfaction  \
# 501                11          2        medical                        1
# 356                 5          4  life sciences                        1
# 476                 8          3  life sciences                        3
# 194                 8          4  life sciences                        3
# 503                 1          4  life sciences                        4
#
#      gender  hourlyrate  jobinvolvement  joblevel  \
# 501    Male          60               3         2
# 356    Male          98               3         2
# 476  Female          54               3         2
# 194  Female          61               3         2
# 503    Male          32               1         2
#
#                          jobrole  jobsatisfaction maritalstatus  \
# 501   healthcare representative                 1       married
# 356             sales executive                 4        single
# 476             sales executive                 2       married
# 194      manufacturing director                 4        single
# 503   healthcare representative                 3      divorced
#
#      monthlyincome  monthlyrate  numcompaniesworked overtime  \
# 501        48620.0        22722                   1       No
# 356        48620.0        20445                   4       No
# 476        48620.0        26841                   5       No
# 194        44240.0        20682                   1       No
# 503        48620.0        17056                   2      Yes
#
#      percentsalaryhike  performancerating  relationshipsatisfaction  \
# 501                 13                3.0                         3
# 356                 21                3.2                         3
# 476                 21                4.0                         3
# 194                 23                4.0                         4
# 503                 13                3.0                         4
#
#      stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 501                 1                5.0                      3
# 356                 0               14.0                      4
# 476                 1               14.0                      3
# 194                 0               11.0                      2
# 503                 1               10.0                      2
#
#      worklifebalance  yearsatcompany  yearssincelastpromotion  \
# 501              3.0               5                        3
# 356              3.0               9                        0
# 476              3.0               5                        1
# 194              3.0              11                        1
# 503              3.0               5                        1
#
#      yearswithcurrmanager  datebirth remotework
# 501                     3       1997        Yes
# 356                     8       1977        Yes
# 476                     4       1982        Yes
# 194                     8       1992         No
# 503                     2       1965        Yes

# %%
# Crear la columna 'group' usando where 

df_ab_testing['group_AB_Testing'] = df_ab_testing['jobsatisfaction'].where(df_ab_testing['jobsatisfaction'] >= 3, 'A').where(df_ab_testing['jobsatisfaction'] < 3, 'B')

# %% [markdown]
# # Grupo A

# %%
# Filtrar el DataFrame para obtener solo los datos del grupo 'A'
grupo_a = df_ab_testing[df_ab_testing['group_AB_Testing'] == 'A']
grupo_a.head(1)
# Out:
#    employeenumber  age attrition businesstravel  dailyrate  distancefromhome  \
# 5             810   59        No  travel rarely     1435.0                25
#
#    education educationfield  environmentsatisfaction  gender  hourlyrate  \
# 5          3  life sciences                        1  Female          99
#
#    jobinvolvement  joblevel            jobrole  jobsatisfaction maritalstatus  \
# 5               3         3   sales executive                 1       married
#
#    monthlyincome  monthlyrate  numcompaniesworked overtime  percentsalaryhike  \
# 5        48620.0         2354                   7       No                 11
#
#    performancerating  relationshipsatisfaction  stockoptionlevel  \
# 5                3.0                         4                 0
#
#    totalworkingyears  trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 5               28.0                      3              2.0              21
#
#    yearssincelastpromotion  yearswithcurrmanager  datebirth remotework  \
# 5                        7                     9       1964        Yes
#
#   group_AB_Testing
# 5                A

# %%
a_convertido = round ((83 / 415), 2) # 2 porcentaje de rotación 
a_convertido
# Out:
# 0.2

# %% [markdown]
# -------------------------

# %% [markdown]
# # Grupo B

# %%
# Filtrar el DataFrame para obtener solo los datos del grupo 'A'
grupo_b = df_ab_testing[df_ab_testing['group_AB_Testing'] == 'B']
grupo_b.head(1)
# Out:
#    employeenumber  age attrition businesstravel  dailyrate  distancefromhome  \
# 0            1620   51        No  travel rarely      684.0                 6
#
#    education educationfield  environmentsatisfaction gender  hourlyrate  \
# 0          3  life sciences                        1   Male          51
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   research director                 3
#
#   maritalstatus  monthlyincome  monthlyrate  numcompaniesworked overtime  \
# 0       married       195370.0         6462                   7       No
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0               10.0                      5
#
#    worklifebalance  yearsatcompany  yearssincelastpromotion  \
# 0              3.0              20                       15
#
#    yearswithcurrmanager  datebirth remotework group_AB_Testing
# 0                    15       1972        Yes                B

# %%
b_convertido = round ((94 / 665), 2) # 2 porcentaje de rotación 
b_convertido
# Out:
# 0.14

# %% [markdown]
# -------------------

# %% [markdown]
# # Test Z

# %%
# Crear una nueva columna 'Group'
df_ab_testing['Group'] = df_ab_testing['jobsatisfaction'].apply(lambda x: 'A' if x >= 3 else 'B')

# Calcular la tasa de rotación para cada grupo
attrition_counts = df_ab_testing.groupby('Group')['attrition'].value_counts().unstack().fillna(0)
print(attrition_counts, '\n')

# Número de empleados con rotación en cada grupo
count_A = attrition_counts.loc['A', 'Yes']
count_B = attrition_counts.loc['B', 'Yes']

# Número total de empleados en cada grupo
n_A = attrition_counts.loc['A'].sum()
n_B = attrition_counts.loc['B'].sum()

# Tasa de rotación en cada grupo
p_A = count_A / n_A
p_B = count_B / n_B
print('Rotación (A):', p_A, 'Rotación (B):', p_B, '\n')

# Tasa de rotación combinada
p_combined = (count_A + count_B) / (n_A + n_B)

# Error estándar de la diferencia de proporciones
se = np.sqrt(p_combined * (1 - p_combined) * (1/n_A + 1/n_B))

# Estadístico Z
z_stat = (p_A - p_B) / se

# p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Z-Statistic: {z_stat}, P-Value: {p_value}" '\n')

# Interpretación de los resultados
if p_value < 0.05:
    print("Existe una diferencia significativa en la tasa de rotación entre los grupos A y B.")
else:
    print("No existe una diferencia significativa en la tasa de rotación entre los grupos A y B.")
# Out:
# attrition   No  Yes
# Group
# A          571   94
# B          332   83
#
# Rotación (A): 0.14135338345864662 Rotación (B): 0.2
#
# Z-Statistic: -2.5325568447279956, P-Value: 0.011323400810056006
#
# Existe una diferencia significativa en la tasa de rotación entre los grupos A y B.
